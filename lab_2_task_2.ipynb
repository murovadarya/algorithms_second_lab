# %%
print(Exhaustive_res)
# Out:
# [0.43, -0.59]

# %%
import random
import numpy as np
import pandas as pd
from numpy.polynomial import polynomial as P
import matplotlib.pyplot as mp
from scipy.optimize import minimize
from typing import List


alpha = random.uniform(0, 1)
betha = random.uniform(0, 1)
b = np.random.normal(0, 1, 100)
print(f'alpha: {alpha}')
print(f'betha: {betha}')

df = pd.DataFrame(columns=('X', 'Y'))

print(df)
print(f'b: {b}, len: {len(b)}, b[0]: {b[0]}')

for k in range(100):
    df.loc[k] = [k / 100, alpha*(k / 100) + betha + b[k]]
print(f'alpha: {alpha}')
print(f'betha: {betha}')
print(f'df: {df}')
print(df['X'][1])

def compute_cost_for_exhaustive(x, y, w, b): 
    # number of training examples
    m = df['Y'].shape[0] 
    
    
    cost_sum = 0
    for i in range(m):
        divider = (b * x[i] + 1)
        if b * x[i] == 1:
            cost = NA
        f_wb = w / divider
        f_wb = round(f_wb, 4)
        cost = (f_wb - y[i]) ** 2
        cost = round(cost)
        cost_sum = cost_sum + cost  

    return cost_sum
def compute_cost(x): 
    # number of training examples
    m = df['Y'].shape[0] 
    
    cost_sum = 0 
    for i in range(m):
        f_wb = x[0] / (df['X'][i] * x[1] + 1)
        cost = (f_wb - df['Y'][i]) ** 2  
        cost_sum = cost_sum + cost  
    return cost_sum

def Nelder_Mead():
    initial_guess = np.array([0, 0])
    Nelder_Mead = minimize(compute_cost, initial_guess, method="Nelder-Mead")
    print(f'Nelder: {Nelder_Mead}')
    return Nelder_Mead.x

def exhaustive_search():
    cost_func_min = 300
    parameter_set = []
    for w in np.arange(0, 1, 0.01):
        w = round(w, 4)
        for b in np.arange(-1, 0, 0.01):
            b = round(b, 4)
            calculate_cost = compute_cost_for_exhaustive(df["X"], df["Y"], w, b)
            print(f'cost calculatred: {calculate_cost}')
            print(f'at parameter set: {w, b}')
            if calculate_cost < cost_func_min:
                cost_func_min = calculate_cost
                parameter_set = [w, b]
    # print(f'parameter_set: {parameter_set}')
#     print(f'cost function minimum: {cost_func_min}')
    return parameter_set


def BFGS():
    initial_guess = np.array([0, 0])

    BFGS = minimize(compute_cost, initial_guess, method="BFGS")
    # print(Nelder_Mead)
    print(f'BFGS: {BFGS}')
    return BFGS.x



Nelder_Mead_res = Nelder_Mead()
Gauss_res = BFGS()
Exhaustive_res = exhaustive_search()


y_Nelder_Mead_res = Nelder_Mead_res[0] / (df['X']*Nelder_Mead_res[1] + 1)
y_Gauss_res = Gauss_res[0] / (df['X']*Gauss_res[1] + 1)
y_Exhaustive_res = ( Exhaustive_res[0] / (df['X'] * Exhaustive_res[1] + 1))



print(Nelder_Mead_res)
print(Gauss_res)
print(round(Nelder_Mead_res[0], 3), round(Nelder_Mead_res[1], 3))
# print(Exhaustive_res)

mp.plot(df["X"], df["Y"],label='Data')
mp.plot(df["X"], y_Nelder_Mead_res, label="Nelder_Mead")
mp.plot(df["X"], y_Gauss_res, label="Gauss")
mp.plot(df["X"], y_Exhaustive_res,label="Exhaustive_res")
mp.xlabel("")
mp.ylabel("Y")
mp.legend()
mp.show()
# Out:
# alpha: 0.36304450786171416
# betha: 0.6606665051590299
# Empty DataFrame
# Columns: [X, Y]
# Index: []
# b: [ 3.96445140e-03 -1.94245004e-01  1.08317093e+00 -7.75539826e-01
#  -3.64398040e-02  4.86584583e-01 -7.07413106e-01 -3.01474987e-01
#  -1.33928429e+00 -1.75727409e+00 -6.26912204e-03 -1.13854056e+00
#  -5.04399786e-01  1.16229156e+00 -2.07604637e+00 -6.37037294e-01
#  -5.69619550e-01 -4.18633802e-01 -1.00170880e+00 -5.35959349e-01
#   1.15932245e-01 -2.99452954e-01 -6.15676088e-01 -4.50119251e-01
#  -1.91370143e-01  6.73952690e-02 -6.54772980e-01  1.40357301e+00
#  -1.92391578e+00  8.94395111e-01 -2.17703360e+00  1.87252726e+00
#  -5.87010569e-01  1.53219479e+00  5.48482014e-01 -1.26853921e+00
#   1.35055182e+00  8.66147645e-01  5.91518333e-01 -1.19164700e+00
#  -4.19578293e-01  4.33488699e-01 -2.01731954e+00  5.64773009e-02
#  -5.15222618e-01 -2.24570946e+00 -2.74265207e-01  1.34111754e+00
#  -4.96487445e-01  1.32065471e+00  2.63528248e-01 -3.51043231e+00
#   1.38064295e-01 -7.25412715e-01 -1.56495660e-01  1.23141018e+00
#   8.18942881e-01 -7.00232462e-01 -2.87684399e-02 -2.37497969e+00
#  -4.02530803e-01 -2.15750539e+00  1.79623550e+00  3.56951357e-01
#   4.56560991e-01 -9.22841955e-01 -7.05948022e-01  1.88861993e+00
#  -5.36982828e-01  3.98171020e-01  3.53609452e-01  1.14433011e-01
#   6.48073314e-01  4.67784339e-01  1.81646523e+00  1.27340595e-01
#   1.20830967e-01  6.12321370e-01 -6.78271423e-01  2.63624876e+00
#  -1.14788939e+00 -1.13300115e-02  2.22415100e-01 -3.89845450e-01
#   9.15462641e-01 -1.00959135e+00 -7.12536836e-01  9.91883953e-01
#  -1.97838143e+00  5.28932530e-01  2.32093708e-01  1.85405810e+00
#   1.29725683e+00 -5.42949946e-01  2.01869729e-03 -1.22872832e+00
#  -1.19576596e+00  1.01183434e+00  5.39680191e-01  7.95979178e-01], len: 100, b[0]: 0.003964451402799477
# alpha: 0.36304450786171416
# betha: 0.6606665051590299
# df:        X         Y
# 0   0.00  0.664631
# 1   0.01  0.470052
# 2   0.02  1.751098
# 3   0.03 -0.103982
# 4   0.04  0.638748
# ..   ...       ...
# 95  0.95 -0.223170
# 96  0.96 -0.186577
# 97  0.97  2.024654
# 98  0.98  1.556130
# 99  0.99  1.816060
#
# [100 rows x 2 columns]
# 0.01
# Nelder:  final_simplex: (array([[ 0.43576789, -0.69876311],
#        [ 0.43583868, -0.69867816],
#        [ 0.43582531, -0.69880458]]), array([117.49061317, 117.49061323, 117.49061431]))
#            fun: 117.4906131651633
#        message: 'Optimization terminated successfully.'
#           nfev: 118
#            nit: 62
#         status: 0
#        success: True
#              x: array([ 0.43576789, -0.69876311])
# BFGS:       fun: 117.49061288144327
#  hess_inv: array([[0.00547163, 0.00543051],
#        [0.00543051, 0.00755655]])
#       jac: array([0.00000000e+00, 9.53674316e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 63
#       nit: 12
#      njev: 21
#    status: 0
#   success: True
#         x: array([ 0.43581173, -0.69874022])
# cost calculatred: 174
# at parameter set: (0.0, -1.0)
# cost calculatred: 174
# at parameter set: (0.0, -0.99)
# cost calculatred: 174
# at parameter set: (0.0, -0.98)
# cost calculatred: 174
# at parameter set: (0.0, -0.97)
# cost calculatred: 174
# at parameter set: (0.0, -0.96)
# cost calculatred: 174
# at parameter set: (0.0, -0.95)
# cost calculatred: 174
# at parameter set: (0.0, -0.94)
# cost calculatred: 174
# at parameter set: (0.0, -0.93)
# cost calculatred: 174
# at parameter set: (0.0, -0.92)
# cost calculatred: 174
# at parameter set: (0.0, -0.91)
# cost calculatred: 174
# at parameter set: (0.0, -0.9)
# cost calculatred: 174
# at parameter set: (0.0, -0.89)
# cost calculatred: 174
# at parameter set: (0.0, -0.88)
# cost calculatred: 174
# at parameter set: (0.0, -0.87)
# cost calculatred: 174
# at parameter set: (0.0, -0.86)
# cost calculatred: 174
# at parameter set: (0.0, -0.85)
# cost calculatred: 174
# at parameter set: (0.0, -0.84)
# cost calculatred: 174
# at parameter set: (0.0, -0.83)
# cost calculatred: 174
# at parameter set: (0.0, -0.82)
# cost calculatred: 174
# at parameter set: (0.0, -0.81)
# cost calculatred: 174
# at parameter set: (0.0, -0.8)
# cost calculatred: 174
# at parameter set: (0.0, -0.79)
# cost calculatred: 174
# at parameter set: (0.0, -0.78)
# cost calculatred: 174
# at parameter set: (0.0, -0.77)
# cost calculatred: 174
# at parameter set: (0.0, -0.76)
# cost calculatred: 174
# at parameter set: (0.0, -0.75)
# cost calculatred: 174
# at parameter set: (0.0, -0.74)
# cost calculatred: 174
# at parameter set: (0.0, -0.73)
# cost calculatred: 174
# at parameter set: (0.0, -0.72)
# cost calculatred: 174
# at parameter set: (0.0, -0.71)
# cost calculatred: 174
# at parameter set: (0.0, -0.7)
# cost calculatred: 174
# at parameter set: (0.0, -0.69)
# cost calculatred: 174
# at parameter set: (0.0, -0.68)
# cost calculatred: 174
# at parameter set: (0.0, -0.67)
# cost calculatred: 174
# at parameter set: (0.0, -0.66)
# cost calculatred: 174
# at parameter set: (0.0, -0.65)
# cost calculatred: 174
# at parameter set: (0.0, -0.64)
# cost calculatred: 174
# at parameter set: (0.0, -0.63)
# cost calculatred: 174
# at parameter set: (0.0, -0.62)
# cost calculatred: 174
# at parameter set: (0.0, -0.61)
# cost calculatred: 174
# at parameter set: (0.0, -0.6)
# cost calculatred: 174
# at parameter set: (0.0, -0.59)
# cost calculatred: 174
# at parameter set: (0.0, -0.58)
# cost calculatred: 174
# at parameter set: (0.0, -0.57)
# cost calculatred: 174
# at parameter set: (0.0, -0.56)
# cost calculatred: 174
# at parameter set: (0.0, -0.55)
# cost calculatred: 174
# at parameter set: (0.0, -0.54)
# cost calculatred: 174
# at parameter set: (0.0, -0.53)
# cost calculatred: 174
# at parameter set: (0.0, -0.52)
# cost calculatred: 174
# at parameter set: (0.0, -0.51)
# cost calculatred: 174
# at parameter set: (0.0, -0.5)
# cost calculatred: 174
# at parameter set: (0.0, -0.49)
# cost calculatred: 174
# at parameter set: (0.0, -0.48)
# cost calculatred: 174
# at parameter set: (0.0, -0.47)
# cost calculatred: 174
# at parameter set: (0.0, -0.46)
# cost calculatred: 174
# at parameter set: (0.0, -0.45)
# cost calculatred: 174
# at parameter set: (0.0, -0.44)
# cost calculatred: 174
# at parameter set: (0.0, -0.43)
# cost calculatred: 174
# at parameter set: (0.0, -0.42)
# cost calculatred: 174
# at parameter set: (0.0, -0.41)
# cost calculatred: 174
# at parameter set: (0.0, -0.4)
# cost calculatred: 174
# at parameter set: (0.0, -0.39)
# cost calculatred: 174
# at parameter set: (0.0, -0.38)
# cost calculatred: 174
# at parameter set: (0.0, -0.37)
# cost calculatred: 174
# at parameter set: (0.0, -0.36)
# cost calculatred: 174
# at parameter set: (0.0, -0.35)
# cost calculatred: 174
# at parameter set: (0.0, -0.34)
# cost calculatred: 174
# at parameter set: (0.0, -0.33)
# cost calculatred: 174
# at parameter set: (0.0, -0.32)
# cost calculatred: 174
# at parameter set: (0.0, -0.31)
# cost calculatred: 174
# at parameter set: (0.0, -0.3)
# cost calculatred: 174
# at parameter set: (0.0, -0.29)
# cost calculatred: 174
# at parameter set: (0.0, -0.28)
# cost calculatred: 174
# at parameter set: (0.0, -0.27)
# cost calculatred: 174
# at parameter set: (0.0, -0.26)
# cost calculatred: 174
# at parameter set: (0.0, -0.25)
# cost calculatred: 174
# at parameter set: (0.0, -0.24)
# cost calculatred: 174
# at parameter set: (0.0, -0.23)
# cost calculatred: 174
# at parameter set: (0.0, -0.22)
# cost calculatred: 174
# at parameter set: (0.0, -0.21)
# cost calculatred: 174
# at parameter set: (0.0, -0.2)
# cost calculatred: 174
# at parameter set: (0.0, -0.19)
# cost calculatred: 174
# at parameter set: (0.0, -0.18)
# cost calculatred: 174
# at parameter set: (0.0, -0.17)
# cost calculatred: 174
# at parameter set: (0.0, -0.16)
# cost calculatred: 174
# at parameter set: (0.0, -0.15)
# cost calculatred: 174
# at parameter set: (0.0, -0.14)
# cost calculatred: 174
# at parameter set: (0.0, -0.13)
# cost calculatred: 174
# at parameter set: (0.0, -0.12)
# cost calculatred: 174
# at parameter set: (0.0, -0.11)
# cost calculatred: 174
# at parameter set: (0.0, -0.1)
# cost calculatred: 174
# at parameter set: (0.0, -0.09)
# cost calculatred: 174
# at parameter set: (0.0, -0.08)
# cost calculatred: 174
# at parameter set: (0.0, -0.07)
# cost calculatred: 174
# at parameter set: (0.0, -0.06)
# cost calculatred: 174
# at parameter set: (0.0, -0.05)
# cost calculatred: 174
# at parameter set: (0.0, -0.04)
# cost calculatred: 174
# at parameter set: (0.0, -0.03)
# cost calculatred: 174
# at parameter set: (0.0, -0.02)
# cost calculatred: 174
# at parameter set: (0.0, -0.01)
# cost calculatred: 166
# at parameter set: (0.01, -1.0)
# cost calculatred: 168
# at parameter set: (0.01, -0.99)
# cost calculatred: 169
# at parameter set: (0.01, -0.98)
# cost calculatred: 169
# at parameter set: (0.01, -0.97)
# cost calculatred: 171
# at parameter set: (0.01, -0.96)
# cost calculatred: 171
# at parameter set: (0.01, -0.95)
# cost calculatred: 171
# at parameter set: (0.01, -0.94)
# cost calculatred: 171
# at parameter set: (0.01, -0.93)
# cost calculatred: 171
# at parameter set: (0.01, -0.92)
# cost calculatred: 171
# at parameter set: (0.01, -0.91)
# cost calculatred: 171
# at parameter set: (0.01, -0.9)
# cost calculatred: 171
# at parameter set: (0.01, -0.89)
# cost calculatred: 171
# at parameter set: (0.01, -0.88)
# cost calculatred: 171
# at parameter set: (0.01, -0.87)
# cost calculatred: 171
# at parameter set: (0.01, -0.86)
# cost calculatred: 172
# at parameter set: (0.01, -0.85)
# cost calculatred: 172
# at parameter set: (0.01, -0.84)
# cost calculatred: 172
# at parameter set: (0.01, -0.83)
# cost calculatred: 172
# at parameter set: (0.01, -0.82)
# cost calculatred: 172
# at parameter set: (0.01, -0.81)
# cost calculatred: 172
# at parameter set: (0.01, -0.8)
# cost calculatred: 172
# at parameter set: (0.01, -0.79)
# cost calculatred: 172
# at parameter set: (0.01, -0.78)
# cost calculatred: 172
# at parameter set: (0.01, -0.77)
# cost calculatred: 172
# at parameter set: (0.01, -0.76)
# cost calculatred: 172
# at parameter set: (0.01, -0.75)
# cost calculatred: 172
# at parameter set: (0.01, -0.74)
# cost calculatred: 172
# at parameter set: (0.01, -0.73)
# cost calculatred: 172
# at parameter set: (0.01, -0.72)
# cost calculatred: 172
# at parameter set: (0.01, -0.71)
# cost calculatred: 172
# at parameter set: (0.01, -0.7)
# cost calculatred: 172
# at parameter set: (0.01, -0.69)
# cost calculatred: 172
# at parameter set: (0.01, -0.68)
# cost calculatred: 172
# at parameter set: (0.01, -0.67)
# cost calculatred: 172
# at parameter set: (0.01, -0.66)
# cost calculatred: 172
# at parameter set: (0.01, -0.65)
# cost calculatred: 172
# at parameter set: (0.01, -0.64)
# cost calculatred: 172
# at parameter set: (0.01, -0.63)
# cost calculatred: 172
# at parameter set: (0.01, -0.62)
# cost calculatred: 172
# at parameter set: (0.01, -0.61)
# cost calculatred: 172
# at parameter set: (0.01, -0.6)
# cost calculatred: 172
# at parameter set: (0.01, -0.59)
# cost calculatred: 172
# at parameter set: (0.01, -0.58)
# cost calculatred: 172
# at parameter set: (0.01, -0.57)
# cost calculatred: 172
# at parameter set: (0.01, -0.56)
# cost calculatred: 172
# at parameter set: (0.01, -0.55)
# cost calculatred: 172
# at parameter set: (0.01, -0.54)
# cost calculatred: 172
# at parameter set: (0.01, -0.53)
# cost calculatred: 172
# at parameter set: (0.01, -0.52)
# cost calculatred: 172
# at parameter set: (0.01, -0.51)
# cost calculatred: 172
# at parameter set: (0.01, -0.5)
# cost calculatred: 172
# at parameter set: (0.01, -0.49)
# cost calculatred: 172
# at parameter set: (0.01, -0.48)
# cost calculatred: 172
# at parameter set: (0.01, -0.47)
# cost calculatred: 172
# at parameter set: (0.01, -0.46)
# cost calculatred: 172
# at parameter set: (0.01, -0.45)
# cost calculatred: 172
# at parameter set: (0.01, -0.44)
# cost calculatred: 172
# at parameter set: (0.01, -0.43)
# cost calculatred: 172
# at parameter set: (0.01, -0.42)
# cost calculatred: 172
# at parameter set: (0.01, -0.41)
# cost calculatred: 172
# at parameter set: (0.01, -0.4)
# cost calculatred: 172
# at parameter set: (0.01, -0.39)
# cost calculatred: 172
# at parameter set: (0.01, -0.38)
# cost calculatred: 172
# at parameter set: (0.01, -0.37)
# cost calculatred: 172
# at parameter set: (0.01, -0.36)
# cost calculatred: 172
# at parameter set: (0.01, -0.35)
# cost calculatred: 172
# at parameter set: (0.01, -0.34)
# cost calculatred: 172
# at parameter set: (0.01, -0.33)
# cost calculatred: 172
# at parameter set: (0.01, -0.32)
# cost calculatred: 172
# at parameter set: (0.01, -0.31)
# cost calculatred: 172
# at parameter set: (0.01, -0.3)
# cost calculatred: 172
# at parameter set: (0.01, -0.29)
# cost calculatred: 172
# at parameter set: (0.01, -0.28)
# cost calculatred: 172
# at parameter set: (0.01, -0.27)
# cost calculatred: 172
# at parameter set: (0.01, -0.26)
# cost calculatred: 172
# at parameter set: (0.01, -0.25)
# cost calculatred: 172
# at parameter set: (0.01, -0.24)
# cost calculatred: 172
# at parameter set: (0.01, -0.23)
# cost calculatred: 172
# at parameter set: (0.01, -0.22)
# cost calculatred: 172
# at parameter set: (0.01, -0.21)
# cost calculatred: 172
# at parameter set: (0.01, -0.2)
# cost calculatred: 172
# at parameter set: (0.01, -0.19)
# cost calculatred: 172
# at parameter set: (0.01, -0.18)
# cost calculatred: 172
# at parameter set: (0.01, -0.17)
# cost calculatred: 172
# at parameter set: (0.01, -0.16)
# cost calculatred: 172
# at parameter set: (0.01, -0.15)
# cost calculatred: 172
# at parameter set: (0.01, -0.14)
# cost calculatred: 172
# at parameter set: (0.01, -0.13)
# cost calculatred: 172
# at parameter set: (0.01, -0.12)
# cost calculatred: 172
# at parameter set: (0.01, -0.11)
# cost calculatred: 172
# at parameter set: (0.01, -0.1)
# cost calculatred: 172
# at parameter set: (0.01, -0.09)
# cost calculatred: 172
# at parameter set: (0.01, -0.08)
# cost calculatred: 172
# at parameter set: (0.01, -0.07)
# cost calculatred: 172
# at parameter set: (0.01, -0.06)
# cost calculatred: 172
# at parameter set: (0.01, -0.05)
# cost calculatred: 172
# at parameter set: (0.01, -0.04)
# cost calculatred: 172
# at parameter set: (0.01, -0.03)
# cost calculatred: 173
# at parameter set: (0.01, -0.02)
# cost calculatred: 173
# at parameter set: (0.01, -0.01)
# cost calculatred: 155
# at parameter set: (0.02, -1.0)
# cost calculatred: 158
# at parameter set: (0.02, -0.99)
# cost calculatred: 159
# at parameter set: (0.02, -0.98)
# cost calculatred: 160
# at parameter set: (0.02, -0.97)
# cost calculatred: 161
# at parameter set: (0.02, -0.96)
# cost calculatred: 163
# at parameter set: (0.02, -0.95)
# cost calculatred: 163
# at parameter set: (0.02, -0.94)
# cost calculatred: 164
# at parameter set: (0.02, -0.93)
# cost calculatred: 165
# at parameter set: (0.02, -0.92)
# cost calculatred: 166
# at parameter set: (0.02, -0.91)
# cost calculatred: 166
# at parameter set: (0.02, -0.9)
# cost calculatred: 168
# at parameter set: (0.02, -0.89)
# cost calculatred: 168
# at parameter set: (0.02, -0.88)
# cost calculatred: 168
# at parameter set: (0.02, -0.87)
# cost calculatred: 168
# at parameter set: (0.02, -0.86)
# cost calculatred: 168
# at parameter set: (0.02, -0.85)
# cost calculatred: 168
# at parameter set: (0.02, -0.84)
# cost calculatred: 168
# at parameter set: (0.02, -0.83)
# cost calculatred: 168
# at parameter set: (0.02, -0.82)
# cost calculatred: 168
# at parameter set: (0.02, -0.81)
# cost calculatred: 168
# at parameter set: (0.02, -0.8)
# cost calculatred: 168
# at parameter set: (0.02, -0.79)
# cost calculatred: 168
# at parameter set: (0.02, -0.78)
# cost calculatred: 169
# at parameter set: (0.02, -0.77)
# cost calculatred: 169
# at parameter set: (0.02, -0.76)
# cost calculatred: 169
# at parameter set: (0.02, -0.75)
# cost calculatred: 170
# at parameter set: (0.02, -0.74)
# cost calculatred: 170
# at parameter set: (0.02, -0.73)
# cost calculatred: 170
# at parameter set: (0.02, -0.72)
# cost calculatred: 170
# at parameter set: (0.02, -0.71)
# cost calculatred: 170
# at parameter set: (0.02, -0.7)
# cost calculatred: 170
# at parameter set: (0.02, -0.69)
# cost calculatred: 170
# at parameter set: (0.02, -0.68)
# cost calculatred: 170
# at parameter set: (0.02, -0.67)
# cost calculatred: 170
# at parameter set: (0.02, -0.66)
# cost calculatred: 170
# at parameter set: (0.02, -0.65)
# cost calculatred: 170
# at parameter set: (0.02, -0.64)
# cost calculatred: 170
# at parameter set: (0.02, -0.63)
# cost calculatred: 170
# at parameter set: (0.02, -0.62)
# cost calculatred: 170
# at parameter set: (0.02, -0.61)
# cost calculatred: 170
# at parameter set: (0.02, -0.6)
# cost calculatred: 170
# at parameter set: (0.02, -0.59)
# cost calculatred: 170
# at parameter set: (0.02, -0.58)
# cost calculatred: 170
# at parameter set: (0.02, -0.57)
# cost calculatred: 170
# at parameter set: (0.02, -0.56)
# cost calculatred: 170
# at parameter set: (0.02, -0.55)
# cost calculatred: 170
# at parameter set: (0.02, -0.54)
# cost calculatred: 170
# at parameter set: (0.02, -0.53)
# cost calculatred: 170
# at parameter set: (0.02, -0.52)
# cost calculatred: 170
# at parameter set: (0.02, -0.51)
# cost calculatred: 170
# at parameter set: (0.02, -0.5)
# cost calculatred: 170
# at parameter set: (0.02, -0.49)
# cost calculatred: 170
# at parameter set: (0.02, -0.48)
# cost calculatred: 170
# at parameter set: (0.02, -0.47)
# cost calculatred: 170
# at parameter set: (0.02, -0.46)
# cost calculatred: 170
# at parameter set: (0.02, -0.45)
# cost calculatred: 170
# at parameter set: (0.02, -0.44)
# cost calculatred: 170
# at parameter set: (0.02, -0.43)
# cost calculatred: 170
# at parameter set: (0.02, -0.42)
# cost calculatred: 170
# at parameter set: (0.02, -0.41)
# cost calculatred: 170
# at parameter set: (0.02, -0.4)
# cost calculatred: 170
# at parameter set: (0.02, -0.39)
# cost calculatred: 170
# at parameter set: (0.02, -0.38)
# cost calculatred: 170
# at parameter set: (0.02, -0.37)
# cost calculatred: 170
# at parameter set: (0.02, -0.36)
# cost calculatred: 170
# at parameter set: (0.02, -0.35)
# cost calculatred: 170
# at parameter set: (0.02, -0.34)
# cost calculatred: 170
# at parameter set: (0.02, -0.33)
# cost calculatred: 170
# at parameter set: (0.02, -0.32)
# cost calculatred: 170
# at parameter set: (0.02, -0.31)
# cost calculatred: 170
# at parameter set: (0.02, -0.3)
# cost calculatred: 170
# at parameter set: (0.02, -0.29)
# cost calculatred: 170
# at parameter set: (0.02, -0.28)
# cost calculatred: 170
# at parameter set: (0.02, -0.27)
# cost calculatred: 170
# at parameter set: (0.02, -0.26)
# cost calculatred: 170
# at parameter set: (0.02, -0.25)
# cost calculatred: 170
# at parameter set: (0.02, -0.24)
# cost calculatred: 170
# at parameter set: (0.02, -0.23)
# cost calculatred: 170
# at parameter set: (0.02, -0.22)
# cost calculatred: 170
# at parameter set: (0.02, -0.21)
# cost calculatred: 170
# at parameter set: (0.02, -0.2)
# cost calculatred: 170
# at parameter set: (0.02, -0.19)
# cost calculatred: 170
# at parameter set: (0.02, -0.18)
# cost calculatred: 170
# at parameter set: (0.02, -0.17)
# cost calculatred: 170
# at parameter set: (0.02, -0.16)
# cost calculatred: 170
# at parameter set: (0.02, -0.15)
# cost calculatred: 170
# at parameter set: (0.02, -0.14)
# cost calculatred: 170
# at parameter set: (0.02, -0.13)
# cost calculatred: 170
# at parameter set: (0.02, -0.12)
# cost calculatred: 171
# at parameter set: (0.02, -0.11)
# cost calculatred: 171
# at parameter set: (0.02, -0.1)
# cost calculatred: 171
# at parameter set: (0.02, -0.09)
# cost calculatred: 171
# at parameter set: (0.02, -0.08)
# cost calculatred: 172
# at parameter set: (0.02, -0.07)
# cost calculatred: 171
# at parameter set: (0.02, -0.06)
# cost calculatred: 171
# at parameter set: (0.02, -0.05)
# cost calculatred: 171
# at parameter set: (0.02, -0.04)
# cost calculatred: 171
# at parameter set: (0.02, -0.03)
# cost calculatred: 171
# at parameter set: (0.02, -0.02)
# cost calculatred: 171
# at parameter set: (0.02, -0.01)
# cost calculatred: 154
# at parameter set: (0.03, -1.0)
# cost calculatred: 155
# at parameter set: (0.03, -0.99)
# cost calculatred: 155
# at parameter set: (0.03, -0.98)
# cost calculatred: 155
# at parameter set: (0.03, -0.97)
# cost calculatred: 156
# at parameter set: (0.03, -0.96)
# cost calculatred: 158
# at parameter set: (0.03, -0.95)
# cost calculatred: 158
# at parameter set: (0.03, -0.94)
# cost calculatred: 159
# at parameter set: (0.03, -0.93)
# cost calculatred: 160
# at parameter set: (0.03, -0.92)
# cost calculatred: 160
# at parameter set: (0.03, -0.91)
# cost calculatred: 160
# at parameter set: (0.03, -0.9)
# cost calculatred: 161
# at parameter set: (0.03, -0.89)
# cost calculatred: 162
# at parameter set: (0.03, -0.88)
# cost calculatred: 163
# at parameter set: (0.03, -0.87)
# cost calculatred: 163
# at parameter set: (0.03, -0.86)
# cost calculatred: 163
# at parameter set: (0.03, -0.85)
# cost calculatred: 163
# at parameter set: (0.03, -0.84)
# cost calculatred: 163
# at parameter set: (0.03, -0.83)
# cost calculatred: 164
# at parameter set: (0.03, -0.82)
# cost calculatred: 164
# at parameter set: (0.03, -0.81)
# cost calculatred: 164
# at parameter set: (0.03, -0.8)
# cost calculatred: 165
# at parameter set: (0.03, -0.79)
# cost calculatred: 166
# at parameter set: (0.03, -0.78)
# cost calculatred: 166
# at parameter set: (0.03, -0.77)
# cost calculatred: 166
# at parameter set: (0.03, -0.76)
# cost calculatred: 166
# at parameter set: (0.03, -0.75)
# cost calculatred: 166
# at parameter set: (0.03, -0.74)
# cost calculatred: 166
# at parameter set: (0.03, -0.73)
# cost calculatred: 166
# at parameter set: (0.03, -0.72)
# cost calculatred: 166
# at parameter set: (0.03, -0.71)
# cost calculatred: 166
# at parameter set: (0.03, -0.7)
# cost calculatred: 166
# at parameter set: (0.03, -0.69)
# cost calculatred: 166
# at parameter set: (0.03, -0.68)
# cost calculatred: 166
# at parameter set: (0.03, -0.67)
# cost calculatred: 167
# at parameter set: (0.03, -0.66)
# cost calculatred: 167
# at parameter set: (0.03, -0.65)
# cost calculatred: 167
# at parameter set: (0.03, -0.64)
# cost calculatred: 167
# at parameter set: (0.03, -0.63)
# cost calculatred: 167
# at parameter set: (0.03, -0.62)
# cost calculatred: 167
# at parameter set: (0.03, -0.61)
# cost calculatred: 167
# at parameter set: (0.03, -0.6)
# cost calculatred: 167
# at parameter set: (0.03, -0.59)
# cost calculatred: 167
# at parameter set: (0.03, -0.58)
# cost calculatred: 167
# at parameter set: (0.03, -0.57)
# cost calculatred: 167
# at parameter set: (0.03, -0.56)
# cost calculatred: 167
# at parameter set: (0.03, -0.55)
# cost calculatred: 167
# at parameter set: (0.03, -0.54)
# cost calculatred: 167
# at parameter set: (0.03, -0.53)
# cost calculatred: 167
# at parameter set: (0.03, -0.52)
# cost calculatred: 167
# at parameter set: (0.03, -0.51)
# cost calculatred: 167
# at parameter set: (0.03, -0.5)
# cost calculatred: 167
# at parameter set: (0.03, -0.49)
# cost calculatred: 167
# at parameter set: (0.03, -0.48)
# cost calculatred: 168
# at parameter set: (0.03, -0.47)
# cost calculatred: 168
# at parameter set: (0.03, -0.46)
# cost calculatred: 168
# at parameter set: (0.03, -0.45)
# cost calculatred: 169
# at parameter set: (0.03, -0.44)
# cost calculatred: 169
# at parameter set: (0.03, -0.43)
# cost calculatred: 170
# at parameter set: (0.03, -0.42)
# cost calculatred: 170
# at parameter set: (0.03, -0.41)
# cost calculatred: 170
# at parameter set: (0.03, -0.4)
# cost calculatred: 170
# at parameter set: (0.03, -0.39)
# cost calculatred: 170
# at parameter set: (0.03, -0.38)
# cost calculatred: 170
# at parameter set: (0.03, -0.37)
# cost calculatred: 170
# at parameter set: (0.03, -0.36)
# cost calculatred: 170
# at parameter set: (0.03, -0.35)
# cost calculatred: 170
# at parameter set: (0.03, -0.34)
# cost calculatred: 170
# at parameter set: (0.03, -0.33)
# cost calculatred: 170
# at parameter set: (0.03, -0.32)
# cost calculatred: 170
# at parameter set: (0.03, -0.31)
# cost calculatred: 170
# at parameter set: (0.03, -0.3)
# cost calculatred: 170
# at parameter set: (0.03, -0.29)
# cost calculatred: 170
# at parameter set: (0.03, -0.28)
# cost calculatred: 170
# at parameter set: (0.03, -0.27)
# cost calculatred: 170
# at parameter set: (0.03, -0.26)
# cost calculatred: 170
# at parameter set: (0.03, -0.25)
# cost calculatred: 170
# at parameter set: (0.03, -0.24)
# cost calculatred: 170
# at parameter set: (0.03, -0.23)
# cost calculatred: 170
# at parameter set: (0.03, -0.22)
# cost calculatred: 170
# at parameter set: (0.03, -0.21)
# cost calculatred: 170
# at parameter set: (0.03, -0.2)
# cost calculatred: 170
# at parameter set: (0.03, -0.19)
# cost calculatred: 170
# at parameter set: (0.03, -0.18)
# cost calculatred: 170
# at parameter set: (0.03, -0.17)
# cost calculatred: 170
# at parameter set: (0.03, -0.16)
# cost calculatred: 170
# at parameter set: (0.03, -0.15)
# cost calculatred: 170
# at parameter set: (0.03, -0.14)
# cost calculatred: 170
# at parameter set: (0.03, -0.13)
# cost calculatred: 170
# at parameter set: (0.03, -0.12)
# cost calculatred: 170
# at parameter set: (0.03, -0.11)
# cost calculatred: 170
# at parameter set: (0.03, -0.1)
# cost calculatred: 170
# at parameter set: (0.03, -0.09)
# cost calculatred: 170
# at parameter set: (0.03, -0.08)
# cost calculatred: 170
# at parameter set: (0.03, -0.07)
# cost calculatred: 170
# at parameter set: (0.03, -0.06)
# cost calculatred: 170
# at parameter set: (0.03, -0.05)
# cost calculatred: 170
# at parameter set: (0.03, -0.04)
# cost calculatred: 170
# at parameter set: (0.03, -0.03)
# cost calculatred: 170
# at parameter set: (0.03, -0.02)
# cost calculatred: 170
# at parameter set: (0.03, -0.01)
# cost calculatred: 157
# at parameter set: (0.04, -1.0)
# cost calculatred: 153
# at parameter set: (0.04, -0.99)
# cost calculatred: 154
# at parameter set: (0.04, -0.98)
# cost calculatred: 157
# at parameter set: (0.04, -0.97)
# cost calculatred: 156
# at parameter set: (0.04, -0.96)
# cost calculatred: 157
# at parameter set: (0.04, -0.95)
# cost calculatred: 158
# at parameter set: (0.04, -0.94)
# cost calculatred: 158
# at parameter set: (0.04, -0.93)
# cost calculatred: 159
# at parameter set: (0.04, -0.92)
# cost calculatred: 159
# at parameter set: (0.04, -0.91)
# cost calculatred: 158
# at parameter set: (0.04, -0.9)
# cost calculatred: 159
# at parameter set: (0.04, -0.89)
# cost calculatred: 159
# at parameter set: (0.04, -0.88)
# cost calculatred: 159
# at parameter set: (0.04, -0.87)
# cost calculatred: 159
# at parameter set: (0.04, -0.86)
# cost calculatred: 158
# at parameter set: (0.04, -0.85)
# cost calculatred: 158
# at parameter set: (0.04, -0.84)
# cost calculatred: 160
# at parameter set: (0.04, -0.83)
# cost calculatred: 160
# at parameter set: (0.04, -0.82)
# cost calculatred: 160
# at parameter set: (0.04, -0.81)
# cost calculatred: 160
# at parameter set: (0.04, -0.8)
# cost calculatred: 160
# at parameter set: (0.04, -0.79)
# cost calculatred: 160
# at parameter set: (0.04, -0.78)
# cost calculatred: 160
# at parameter set: (0.04, -0.77)
# cost calculatred: 162
# at parameter set: (0.04, -0.76)
# cost calculatred: 162
# at parameter set: (0.04, -0.75)
# cost calculatred: 162
# at parameter set: (0.04, -0.74)
# cost calculatred: 162
# at parameter set: (0.04, -0.73)
# cost calculatred: 162
# at parameter set: (0.04, -0.72)
# cost calculatred: 162
# at parameter set: (0.04, -0.71)
# cost calculatred: 162
# at parameter set: (0.04, -0.7)
# cost calculatred: 162
# at parameter set: (0.04, -0.69)
# cost calculatred: 163
# at parameter set: (0.04, -0.68)
# cost calculatred: 164
# at parameter set: (0.04, -0.67)
# cost calculatred: 164
# at parameter set: (0.04, -0.66)
# cost calculatred: 164
# at parameter set: (0.04, -0.65)
# cost calculatred: 164
# at parameter set: (0.04, -0.64)
# cost calculatred: 164
# at parameter set: (0.04, -0.63)
# cost calculatred: 164
# at parameter set: (0.04, -0.62)
# cost calculatred: 164
# at parameter set: (0.04, -0.61)
# cost calculatred: 164
# at parameter set: (0.04, -0.6)
# cost calculatred: 164
# at parameter set: (0.04, -0.59)
# cost calculatred: 164
# at parameter set: (0.04, -0.58)
# cost calculatred: 164
# at parameter set: (0.04, -0.57)
# cost calculatred: 164
# at parameter set: (0.04, -0.56)
# cost calculatred: 164
# at parameter set: (0.04, -0.55)
# cost calculatred: 164
# at parameter set: (0.04, -0.54)
# cost calculatred: 164
# at parameter set: (0.04, -0.53)
# cost calculatred: 164
# at parameter set: (0.04, -0.52)
# cost calculatred: 164
# at parameter set: (0.04, -0.51)
# cost calculatred: 164
# at parameter set: (0.04, -0.5)
# cost calculatred: 164
# at parameter set: (0.04, -0.49)
# cost calculatred: 164
# at parameter set: (0.04, -0.48)
# cost calculatred: 164
# at parameter set: (0.04, -0.47)
# cost calculatred: 165
# at parameter set: (0.04, -0.46)
# cost calculatred: 165
# at parameter set: (0.04, -0.45)
# cost calculatred: 165
# at parameter set: (0.04, -0.44)
# cost calculatred: 165
# at parameter set: (0.04, -0.43)
# cost calculatred: 165
# at parameter set: (0.04, -0.42)
# cost calculatred: 165
# at parameter set: (0.04, -0.41)
# cost calculatred: 165
# at parameter set: (0.04, -0.4)
# cost calculatred: 165
# at parameter set: (0.04, -0.39)
# cost calculatred: 166
# at parameter set: (0.04, -0.38)
# cost calculatred: 166
# at parameter set: (0.04, -0.37)
# cost calculatred: 166
# at parameter set: (0.04, -0.36)
# cost calculatred: 166
# at parameter set: (0.04, -0.35)
# cost calculatred: 166
# at parameter set: (0.04, -0.34)
# cost calculatred: 166
# at parameter set: (0.04, -0.33)
# cost calculatred: 166
# at parameter set: (0.04, -0.32)
# cost calculatred: 166
# at parameter set: (0.04, -0.31)
# cost calculatred: 166
# at parameter set: (0.04, -0.3)
# cost calculatred: 166
# at parameter set: (0.04, -0.29)
# cost calculatred: 166
# at parameter set: (0.04, -0.28)
# cost calculatred: 166
# at parameter set: (0.04, -0.27)
# cost calculatred: 166
# at parameter set: (0.04, -0.26)
# cost calculatred: 166
# at parameter set: (0.04, -0.25)
# cost calculatred: 166
# at parameter set: (0.04, -0.24)
# cost calculatred: 166
# at parameter set: (0.04, -0.23)
# cost calculatred: 166
# at parameter set: (0.04, -0.22)
# cost calculatred: 167
# at parameter set: (0.04, -0.21)
# cost calculatred: 167
# at parameter set: (0.04, -0.2)
# cost calculatred: 167
# at parameter set: (0.04, -0.19)
# cost calculatred: 167
# at parameter set: (0.04, -0.18)
# cost calculatred: 167
# at parameter set: (0.04, -0.17)
# cost calculatred: 167
# at parameter set: (0.04, -0.16)
# cost calculatred: 167
# at parameter set: (0.04, -0.15)
# cost calculatred: 167
# at parameter set: (0.04, -0.14)
# cost calculatred: 167
# at parameter set: (0.04, -0.13)
# cost calculatred: 167
# at parameter set: (0.04, -0.12)
# cost calculatred: 168
# at parameter set: (0.04, -0.11)
# cost calculatred: 168
# at parameter set: (0.04, -0.1)
# cost calculatred: 168
# at parameter set: (0.04, -0.09)
# cost calculatred: 169
# at parameter set: (0.04, -0.08)
# cost calculatred: 169
# at parameter set: (0.04, -0.07)
# cost calculatred: 169
# at parameter set: (0.04, -0.06)
# cost calculatred: 169
# at parameter set: (0.04, -0.05)
# cost calculatred: 169
# at parameter set: (0.04, -0.04)
# cost calculatred: 169
# at parameter set: (0.04, -0.03)
# cost calculatred: 169
# at parameter set: (0.04, -0.02)
# cost calculatred: 169
# at parameter set: (0.04, -0.01)
# cost calculatred: 158
# at parameter set: (0.05, -1.0)
# cost calculatred: 148
# at parameter set: (0.05, -0.99)
# cost calculatred: 149
# at parameter set: (0.05, -0.98)
# cost calculatred: 150
# at parameter set: (0.05, -0.97)
# cost calculatred: 154
# at parameter set: (0.05, -0.96)
# cost calculatred: 155
# at parameter set: (0.05, -0.95)
# cost calculatred: 153
# at parameter set: (0.05, -0.94)
# cost calculatred: 155
# at parameter set: (0.05, -0.93)
# cost calculatred: 157
# at parameter set: (0.05, -0.92)
# cost calculatred: 159
# at parameter set: (0.05, -0.91)
# cost calculatred: 160
# at parameter set: (0.05, -0.9)
# cost calculatred: 160
# at parameter set: (0.05, -0.89)
# cost calculatred: 160
# at parameter set: (0.05, -0.88)
# cost calculatred: 160
# at parameter set: (0.05, -0.87)
# cost calculatred: 161
# at parameter set: (0.05, -0.86)
# cost calculatred: 161
# at parameter set: (0.05, -0.85)
# cost calculatred: 161
# at parameter set: (0.05, -0.84)
# cost calculatred: 161
# at parameter set: (0.05, -0.83)
# cost calculatred: 161
# at parameter set: (0.05, -0.82)
# cost calculatred: 161
# at parameter set: (0.05, -0.81)
# cost calculatred: 161
# at parameter set: (0.05, -0.8)
# cost calculatred: 162
# at parameter set: (0.05, -0.79)
# cost calculatred: 162
# at parameter set: (0.05, -0.78)
# cost calculatred: 162
# at parameter set: (0.05, -0.77)
# cost calculatred: 163
# at parameter set: (0.05, -0.76)
# cost calculatred: 163
# at parameter set: (0.05, -0.75)
# cost calculatred: 162
# at parameter set: (0.05, -0.74)
# cost calculatred: 162
# at parameter set: (0.05, -0.73)
# cost calculatred: 162
# at parameter set: (0.05, -0.72)
# cost calculatred: 162
# at parameter set: (0.05, -0.71)
# cost calculatred: 162
# at parameter set: (0.05, -0.7)
# cost calculatred: 163
# at parameter set: (0.05, -0.69)
# cost calculatred: 163
# at parameter set: (0.05, -0.68)
# cost calculatred: 163
# at parameter set: (0.05, -0.67)
# cost calculatred: 163
# at parameter set: (0.05, -0.66)
# cost calculatred: 163
# at parameter set: (0.05, -0.65)
# cost calculatred: 162
# at parameter set: (0.05, -0.64)
# cost calculatred: 161
# at parameter set: (0.05, -0.63)
# cost calculatred: 161
# at parameter set: (0.05, -0.62)
# cost calculatred: 161
# at parameter set: (0.05, -0.61)
# cost calculatred: 161
# at parameter set: (0.05, -0.6)
# cost calculatred: 162
# at parameter set: (0.05, -0.59)
# cost calculatred: 163
# at parameter set: (0.05, -0.58)
# cost calculatred: 163
# at parameter set: (0.05, -0.57)
# cost calculatred: 164
# at parameter set: (0.05, -0.56)
# cost calculatred: 164
# at parameter set: (0.05, -0.55)
# cost calculatred: 164
# at parameter set: (0.05, -0.54)
# cost calculatred: 164
# at parameter set: (0.05, -0.53)
# cost calculatred: 164
# at parameter set: (0.05, -0.52)
# cost calculatred: 164
# at parameter set: (0.05, -0.51)
# cost calculatred: 164
# at parameter set: (0.05, -0.5)
# cost calculatred: 164
# at parameter set: (0.05, -0.49)
# cost calculatred: 164
# at parameter set: (0.05, -0.48)
# cost calculatred: 164
# at parameter set: (0.05, -0.47)
# cost calculatred: 164
# at parameter set: (0.05, -0.46)
# cost calculatred: 164
# at parameter set: (0.05, -0.45)
# cost calculatred: 164
# at parameter set: (0.05, -0.44)
# cost calculatred: 164
# at parameter set: (0.05, -0.43)
# cost calculatred: 164
# at parameter set: (0.05, -0.42)
# cost calculatred: 164
# at parameter set: (0.05, -0.41)
# cost calculatred: 164
# at parameter set: (0.05, -0.4)
# cost calculatred: 164
# at parameter set: (0.05, -0.39)
# cost calculatred: 164
# at parameter set: (0.05, -0.38)
# cost calculatred: 164
# at parameter set: (0.05, -0.37)
# cost calculatred: 164
# at parameter set: (0.05, -0.36)
# cost calculatred: 164
# at parameter set: (0.05, -0.35)
# cost calculatred: 164
# at parameter set: (0.05, -0.34)
# cost calculatred: 164
# at parameter set: (0.05, -0.33)
# cost calculatred: 164
# at parameter set: (0.05, -0.32)
# cost calculatred: 164
# at parameter set: (0.05, -0.31)
# cost calculatred: 164
# at parameter set: (0.05, -0.3)
# cost calculatred: 164
# at parameter set: (0.05, -0.29)
# cost calculatred: 164
# at parameter set: (0.05, -0.28)
# cost calculatred: 164
# at parameter set: (0.05, -0.27)
# cost calculatred: 164
# at parameter set: (0.05, -0.26)
# cost calculatred: 164
# at parameter set: (0.05, -0.25)
# cost calculatred: 164
# at parameter set: (0.05, -0.24)
# cost calculatred: 164
# at parameter set: (0.05, -0.23)
# cost calculatred: 164
# at parameter set: (0.05, -0.22)
# cost calculatred: 164
# at parameter set: (0.05, -0.21)
# cost calculatred: 164
# at parameter set: (0.05, -0.2)
# cost calculatred: 164
# at parameter set: (0.05, -0.19)
# cost calculatred: 164
# at parameter set: (0.05, -0.18)
# cost calculatred: 164
# at parameter set: (0.05, -0.17)
# cost calculatred: 164
# at parameter set: (0.05, -0.16)
# cost calculatred: 164
# at parameter set: (0.05, -0.15)
# cost calculatred: 164
# at parameter set: (0.05, -0.14)
# cost calculatred: 164
# at parameter set: (0.05, -0.13)
# cost calculatred: 164
# at parameter set: (0.05, -0.12)
# cost calculatred: 164
# at parameter set: (0.05, -0.11)
# cost calculatred: 165
# at parameter set: (0.05, -0.1)
# cost calculatred: 165
# at parameter set: (0.05, -0.09)
# cost calculatred: 165
# at parameter set: (0.05, -0.08)
# cost calculatred: 165
# at parameter set: (0.05, -0.07)
# cost calculatred: 165
# at parameter set: (0.05, -0.06)
# cost calculatred: 165
# at parameter set: (0.05, -0.05)
# cost calculatred: 166
# at parameter set: (0.05, -0.04)
# cost calculatred: 166
# at parameter set: (0.05, -0.03)
# cost calculatred: 166
# at parameter set: (0.05, -0.02)
# cost calculatred: 166
# at parameter set: (0.05, -0.01)
# cost calculatred: 162
# at parameter set: (0.06, -1.0)
# cost calculatred: 143
# at parameter set: (0.06, -0.99)
# cost calculatred: 142
# at parameter set: (0.06, -0.98)
# cost calculatred: 143
# at parameter set: (0.06, -0.97)
# cost calculatred: 144
# at parameter set: (0.06, -0.96)
# cost calculatred: 148
# at parameter set: (0.06, -0.95)
# cost calculatred: 149
# at parameter set: (0.06, -0.94)
# cost calculatred: 151
# at parameter set: (0.06, -0.93)
# cost calculatred: 150
# at parameter set: (0.06, -0.92)
# cost calculatred: 150
# at parameter set: (0.06, -0.91)
# cost calculatred: 151
# at parameter set: (0.06, -0.9)
# cost calculatred: 152
# at parameter set: (0.06, -0.89)
# cost calculatred: 155
# at parameter set: (0.06, -0.88)
# cost calculatred: 157
# at parameter set: (0.06, -0.87)
# cost calculatred: 157
# at parameter set: (0.06, -0.86)
# cost calculatred: 157
# at parameter set: (0.06, -0.85)
# cost calculatred: 158
# at parameter set: (0.06, -0.84)
# cost calculatred: 159
# at parameter set: (0.06, -0.83)
# cost calculatred: 159
# at parameter set: (0.06, -0.82)
# cost calculatred: 160
# at parameter set: (0.06, -0.81)
# cost calculatred: 160
# at parameter set: (0.06, -0.8)
# cost calculatred: 160
# at parameter set: (0.06, -0.79)
# cost calculatred: 160
# at parameter set: (0.06, -0.78)
# cost calculatred: 160
# at parameter set: (0.06, -0.77)
# cost calculatred: 160
# at parameter set: (0.06, -0.76)
# cost calculatred: 161
# at parameter set: (0.06, -0.75)
# cost calculatred: 161
# at parameter set: (0.06, -0.74)
# cost calculatred: 162
# at parameter set: (0.06, -0.73)
# cost calculatred: 162
# at parameter set: (0.06, -0.72)
# cost calculatred: 162
# at parameter set: (0.06, -0.71)
# cost calculatred: 163
# at parameter set: (0.06, -0.7)
# cost calculatred: 163
# at parameter set: (0.06, -0.69)
# cost calculatred: 163
# at parameter set: (0.06, -0.68)
# cost calculatred: 164
# at parameter set: (0.06, -0.67)
# cost calculatred: 164
# at parameter set: (0.06, -0.66)
# cost calculatred: 164
# at parameter set: (0.06, -0.65)
# cost calculatred: 164
# at parameter set: (0.06, -0.64)
# cost calculatred: 164
# at parameter set: (0.06, -0.63)
# cost calculatred: 165
# at parameter set: (0.06, -0.62)
# cost calculatred: 165
# at parameter set: (0.06, -0.61)
# cost calculatred: 165
# at parameter set: (0.06, -0.6)
# cost calculatred: 165
# at parameter set: (0.06, -0.59)
# cost calculatred: 165
# at parameter set: (0.06, -0.58)
# cost calculatred: 165
# at parameter set: (0.06, -0.57)
# cost calculatred: 165
# at parameter set: (0.06, -0.56)
# cost calculatred: 165
# at parameter set: (0.06, -0.55)
# cost calculatred: 165
# at parameter set: (0.06, -0.54)
# cost calculatred: 165
# at parameter set: (0.06, -0.53)
# cost calculatred: 165
# at parameter set: (0.06, -0.52)
# cost calculatred: 165
# at parameter set: (0.06, -0.51)
# cost calculatred: 165
# at parameter set: (0.06, -0.5)
# cost calculatred: 165
# at parameter set: (0.06, -0.49)
# cost calculatred: 165
# at parameter set: (0.06, -0.48)
# cost calculatred: 166
# at parameter set: (0.06, -0.47)
# cost calculatred: 166
# at parameter set: (0.06, -0.46)
# cost calculatred: 166
# at parameter set: (0.06, -0.45)
# cost calculatred: 166
# at parameter set: (0.06, -0.44)
# cost calculatred: 166
# at parameter set: (0.06, -0.43)
# cost calculatred: 167
# at parameter set: (0.06, -0.42)
# cost calculatred: 167
# at parameter set: (0.06, -0.41)
# cost calculatred: 167
# at parameter set: (0.06, -0.4)
# cost calculatred: 167
# at parameter set: (0.06, -0.39)
# cost calculatred: 167
# at parameter set: (0.06, -0.38)
# cost calculatred: 167
# at parameter set: (0.06, -0.37)
# cost calculatred: 166
# at parameter set: (0.06, -0.36)
# cost calculatred: 166
# at parameter set: (0.06, -0.35)
# cost calculatred: 166
# at parameter set: (0.06, -0.34)
# cost calculatred: 166
# at parameter set: (0.06, -0.33)
# cost calculatred: 166
# at parameter set: (0.06, -0.32)
# cost calculatred: 166
# at parameter set: (0.06, -0.31)
# cost calculatred: 166
# at parameter set: (0.06, -0.3)
# cost calculatred: 166
# at parameter set: (0.06, -0.29)
# cost calculatred: 166
# at parameter set: (0.06, -0.28)
# cost calculatred: 166
# at parameter set: (0.06, -0.27)
# cost calculatred: 166
# at parameter set: (0.06, -0.26)
# cost calculatred: 166
# at parameter set: (0.06, -0.25)
# cost calculatred: 166
# at parameter set: (0.06, -0.24)
# cost calculatred: 166
# at parameter set: (0.06, -0.23)
# cost calculatred: 166
# at parameter set: (0.06, -0.22)
# cost calculatred: 166
# at parameter set: (0.06, -0.21)
# cost calculatred: 166
# at parameter set: (0.06, -0.2)
# cost calculatred: 166
# at parameter set: (0.06, -0.19)
# cost calculatred: 166
# at parameter set: (0.06, -0.18)
# cost calculatred: 165
# at parameter set: (0.06, -0.17)
# cost calculatred: 165
# at parameter set: (0.06, -0.16)
# cost calculatred: 165
# at parameter set: (0.06, -0.15)
# cost calculatred: 165
# at parameter set: (0.06, -0.14)
# cost calculatred: 165
# at parameter set: (0.06, -0.13)
# cost calculatred: 165
# at parameter set: (0.06, -0.12)
# cost calculatred: 165
# at parameter set: (0.06, -0.11)
# cost calculatred: 165
# at parameter set: (0.06, -0.1)
# cost calculatred: 165
# at parameter set: (0.06, -0.09)
# cost calculatred: 165
# at parameter set: (0.06, -0.08)
# cost calculatred: 165
# at parameter set: (0.06, -0.07)
# cost calculatred: 165
# at parameter set: (0.06, -0.06)
# cost calculatred: 165
# at parameter set: (0.06, -0.05)
# cost calculatred: 165
# at parameter set: (0.06, -0.04)
# cost calculatred: 165
# at parameter set: (0.06, -0.03)
# cost calculatred: 165
# at parameter set: (0.06, -0.02)
# cost calculatred: 165
# at parameter set: (0.06, -0.01)
# cost calculatred: 174
# at parameter set: (0.07, -1.0)
# cost calculatred: 145
# at parameter set: (0.07, -0.99)
# cost calculatred: 140
# at parameter set: (0.07, -0.98)
# cost calculatred: 140
# at parameter set: (0.07, -0.97)
# cost calculatred: 140
# at parameter set: (0.07, -0.96)
# cost calculatred: 141
# at parameter set: (0.07, -0.95)
# cost calculatred: 145
# at parameter set: (0.07, -0.94)
# cost calculatred: 146
# at parameter set: (0.07, -0.93)
# cost calculatred: 146
# at parameter set: (0.07, -0.92)
# cost calculatred: 147
# at parameter set: (0.07, -0.91)
# cost calculatred: 146
# at parameter set: (0.07, -0.9)
# cost calculatred: 147
# at parameter set: (0.07, -0.89)
# cost calculatred: 147
# at parameter set: (0.07, -0.88)
# cost calculatred: 148
# at parameter set: (0.07, -0.87)
# cost calculatred: 151
# at parameter set: (0.07, -0.86)
# cost calculatred: 152
# at parameter set: (0.07, -0.85)
# cost calculatred: 152
# at parameter set: (0.07, -0.84)
# cost calculatred: 154
# at parameter set: (0.07, -0.83)
# cost calculatred: 154
# at parameter set: (0.07, -0.82)
# cost calculatred: 155
# at parameter set: (0.07, -0.81)
# cost calculatred: 158
# at parameter set: (0.07, -0.8)
# cost calculatred: 158
# at parameter set: (0.07, -0.79)
# cost calculatred: 157
# at parameter set: (0.07, -0.78)
# cost calculatred: 157
# at parameter set: (0.07, -0.77)
# cost calculatred: 158
# at parameter set: (0.07, -0.76)
# cost calculatred: 158
# at parameter set: (0.07, -0.75)
# cost calculatred: 158
# at parameter set: (0.07, -0.74)
# cost calculatred: 158
# at parameter set: (0.07, -0.73)
# cost calculatred: 158
# at parameter set: (0.07, -0.72)
# cost calculatred: 158
# at parameter set: (0.07, -0.71)
# cost calculatred: 159
# at parameter set: (0.07, -0.7)
# cost calculatred: 159
# at parameter set: (0.07, -0.69)
# cost calculatred: 160
# at parameter set: (0.07, -0.68)
# cost calculatred: 160
# at parameter set: (0.07, -0.67)
# cost calculatred: 160
# at parameter set: (0.07, -0.66)
# cost calculatred: 160
# at parameter set: (0.07, -0.65)
# cost calculatred: 161
# at parameter set: (0.07, -0.64)
# cost calculatred: 161
# at parameter set: (0.07, -0.63)
# cost calculatred: 161
# at parameter set: (0.07, -0.62)
# cost calculatred: 161
# at parameter set: (0.07, -0.61)
# cost calculatred: 161
# at parameter set: (0.07, -0.6)
# cost calculatred: 161
# at parameter set: (0.07, -0.59)
# cost calculatred: 161
# at parameter set: (0.07, -0.58)
# cost calculatred: 161
# at parameter set: (0.07, -0.57)
# cost calculatred: 162
# at parameter set: (0.07, -0.56)
# cost calculatred: 163
# at parameter set: (0.07, -0.55)
# cost calculatred: 163
# at parameter set: (0.07, -0.54)
# cost calculatred: 163
# at parameter set: (0.07, -0.53)
# cost calculatred: 163
# at parameter set: (0.07, -0.52)
# cost calculatred: 163
# at parameter set: (0.07, -0.51)
# cost calculatred: 163
# at parameter set: (0.07, -0.5)
# cost calculatred: 163
# at parameter set: (0.07, -0.49)
# cost calculatred: 163
# at parameter set: (0.07, -0.48)
# cost calculatred: 163
# at parameter set: (0.07, -0.47)
# cost calculatred: 163
# at parameter set: (0.07, -0.46)
# cost calculatred: 163
# at parameter set: (0.07, -0.45)
# cost calculatred: 163
# at parameter set: (0.07, -0.44)
# cost calculatred: 163
# at parameter set: (0.07, -0.43)
# cost calculatred: 163
# at parameter set: (0.07, -0.42)
# cost calculatred: 163
# at parameter set: (0.07, -0.41)
# cost calculatred: 164
# at parameter set: (0.07, -0.4)
# cost calculatred: 164
# at parameter set: (0.07, -0.39)
# cost calculatred: 164
# at parameter set: (0.07, -0.38)
# cost calculatred: 165
# at parameter set: (0.07, -0.37)
# cost calculatred: 165
# at parameter set: (0.07, -0.36)
# cost calculatred: 165
# at parameter set: (0.07, -0.35)
# cost calculatred: 165
# at parameter set: (0.07, -0.34)
# cost calculatred: 166
# at parameter set: (0.07, -0.33)
# cost calculatred: 167
# at parameter set: (0.07, -0.32)
# cost calculatred: 167
# at parameter set: (0.07, -0.31)
# cost calculatred: 167
# at parameter set: (0.07, -0.3)
# cost calculatred: 167
# at parameter set: (0.07, -0.29)
# cost calculatred: 167
# at parameter set: (0.07, -0.28)
# cost calculatred: 167
# at parameter set: (0.07, -0.27)
# cost calculatred: 167
# at parameter set: (0.07, -0.26)
# cost calculatred: 167
# at parameter set: (0.07, -0.25)
# cost calculatred: 168
# at parameter set: (0.07, -0.24)
# cost calculatred: 167
# at parameter set: (0.07, -0.23)
# cost calculatred: 167
# at parameter set: (0.07, -0.22)
# cost calculatred: 167
# at parameter set: (0.07, -0.21)
# cost calculatred: 167
# at parameter set: (0.07, -0.2)
# cost calculatred: 167
# at parameter set: (0.07, -0.19)
# cost calculatred: 167
# at parameter set: (0.07, -0.18)
# cost calculatred: 167
# at parameter set: (0.07, -0.17)
# cost calculatred: 167
# at parameter set: (0.07, -0.16)
# cost calculatred: 167
# at parameter set: (0.07, -0.15)
# cost calculatred: 167
# at parameter set: (0.07, -0.14)
# cost calculatred: 167
# at parameter set: (0.07, -0.13)
# cost calculatred: 167
# at parameter set: (0.07, -0.12)
# cost calculatred: 167
# at parameter set: (0.07, -0.11)
# cost calculatred: 166
# at parameter set: (0.07, -0.1)
# cost calculatred: 166
# at parameter set: (0.07, -0.09)
# cost calculatred: 166
# at parameter set: (0.07, -0.08)
# cost calculatred: 166
# at parameter set: (0.07, -0.07)
# cost calculatred: 166
# at parameter set: (0.07, -0.06)
# cost calculatred: 166
# at parameter set: (0.07, -0.05)
# cost calculatred: 166
# at parameter set: (0.07, -0.04)
# cost calculatred: 166
# at parameter set: (0.07, -0.03)
# cost calculatred: 166
# at parameter set: (0.07, -0.02)
# cost calculatred: 166
# at parameter set: (0.07, -0.01)
# cost calculatred: 185
# at parameter set: (0.08, -1.0)
# cost calculatred: 144
# at parameter set: (0.08, -0.99)
# cost calculatred: 138
# at parameter set: (0.08, -0.98)
# cost calculatred: 139
# at parameter set: (0.08, -0.97)
# cost calculatred: 139
# at parameter set: (0.08, -0.96)
# cost calculatred: 139
# at parameter set: (0.08, -0.95)
# cost calculatred: 139
# at parameter set: (0.08, -0.94)
# cost calculatred: 141
# at parameter set: (0.08, -0.93)
# cost calculatred: 144
# at parameter set: (0.08, -0.92)
# cost calculatred: 145
# at parameter set: (0.08, -0.91)
# cost calculatred: 145
# at parameter set: (0.08, -0.9)
# cost calculatred: 145
# at parameter set: (0.08, -0.89)
# cost calculatred: 145
# at parameter set: (0.08, -0.88)
# cost calculatred: 146
# at parameter set: (0.08, -0.87)
# cost calculatred: 146
# at parameter set: (0.08, -0.86)
# cost calculatred: 146
# at parameter set: (0.08, -0.85)
# cost calculatred: 147
# at parameter set: (0.08, -0.84)
# cost calculatred: 147
# at parameter set: (0.08, -0.83)
# cost calculatred: 147
# at parameter set: (0.08, -0.82)
# cost calculatred: 149
# at parameter set: (0.08, -0.81)
# cost calculatred: 151
# at parameter set: (0.08, -0.8)
# cost calculatred: 151
# at parameter set: (0.08, -0.79)
# cost calculatred: 151
# at parameter set: (0.08, -0.78)
# cost calculatred: 153
# at parameter set: (0.08, -0.77)
# cost calculatred: 153
# at parameter set: (0.08, -0.76)
# cost calculatred: 154
# at parameter set: (0.08, -0.75)
# cost calculatred: 154
# at parameter set: (0.08, -0.74)
# cost calculatred: 154
# at parameter set: (0.08, -0.73)
# cost calculatred: 155
# at parameter set: (0.08, -0.72)
# cost calculatred: 155
# at parameter set: (0.08, -0.71)
# cost calculatred: 156
# at parameter set: (0.08, -0.7)
# cost calculatred: 156
# at parameter set: (0.08, -0.69)
# cost calculatred: 156
# at parameter set: (0.08, -0.68)
# cost calculatred: 156
# at parameter set: (0.08, -0.67)
# cost calculatred: 157
# at parameter set: (0.08, -0.66)
# cost calculatred: 157
# at parameter set: (0.08, -0.65)
# cost calculatred: 157
# at parameter set: (0.08, -0.64)
# cost calculatred: 158
# at parameter set: (0.08, -0.63)
# cost calculatred: 158
# at parameter set: (0.08, -0.62)
# cost calculatred: 158
# at parameter set: (0.08, -0.61)
# ...
# cost calculatred: 1315
# at parameter set: (0.97, -0.95)
# cost calculatred: 1090
# at parameter set: (0.97, -0.94)
# cost calculatred: 922
# at parameter set: (0.97, -0.93)
# cost calculatred: 799
# at parameter set: (0.97, -0.92)
# cost calculatred: 703
# at parameter set: (0.97, -0.91)
# cost calculatred: 626
# at parameter set: (0.97, -0.9)
# cost calculatred: 563
# at parameter set: (0.97, -0.89)
# cost calculatred: 511
# at parameter set: (0.97, -0.88)
# cost calculatred: 469
# at parameter set: (0.97, -0.87)
# cost calculatred: 433
# at parameter set: (0.97, -0.86)
# cost calculatred: 404
# at parameter set: (0.97, -0.85)
# cost calculatred: 378
# at parameter set: (0.97, -0.84)
# cost calculatred: 354
# at parameter set: (0.97, -0.83)
# cost calculatred: 333
# at parameter set: (0.97, -0.82)
# cost calculatred: 319
# at parameter set: (0.97, -0.81)
# cost calculatred: 298
# at parameter set: (0.97, -0.8)
# cost calculatred: 287
# at parameter set: (0.97, -0.79)
# cost calculatred: 275
# at parameter set: (0.97, -0.78)
# cost calculatred: 263
# at parameter set: (0.97, -0.77)
# cost calculatred: 252
# at parameter set: (0.97, -0.76)
# cost calculatred: 242
# at parameter set: (0.97, -0.75)
# cost calculatred: 237
# at parameter set: (0.97, -0.74)
# cost calculatred: 228
# at parameter set: (0.97, -0.73)
# cost calculatred: 214
# at parameter set: (0.97, -0.72)
# cost calculatred: 212
# at parameter set: (0.97, -0.71)
# cost calculatred: 208
# at parameter set: (0.97, -0.7)
# cost calculatred: 205
# at parameter set: (0.97, -0.69)
# cost calculatred: 199
# at parameter set: (0.97, -0.68)
# cost calculatred: 195
# at parameter set: (0.97, -0.67)
# cost calculatred: 189
# at parameter set: (0.97, -0.66)
# cost calculatred: 189
# at parameter set: (0.97, -0.65)
# cost calculatred: 184
# at parameter set: (0.97, -0.64)
# cost calculatred: 182
# at parameter set: (0.97, -0.63)
# cost calculatred: 178
# at parameter set: (0.97, -0.62)
# cost calculatred: 175
# at parameter set: (0.97, -0.61)
# cost calculatred: 172
# at parameter set: (0.97, -0.6)
# cost calculatred: 169
# at parameter set: (0.97, -0.59)
# cost calculatred: 167
# at parameter set: (0.97, -0.58)
# cost calculatred: 162
# at parameter set: (0.97, -0.57)
# cost calculatred: 161
# at parameter set: (0.97, -0.56)
# cost calculatred: 156
# at parameter set: (0.97, -0.55)
# cost calculatred: 158
# at parameter set: (0.97, -0.54)
# cost calculatred: 156
# at parameter set: (0.97, -0.53)
# cost calculatred: 155
# at parameter set: (0.97, -0.52)
# cost calculatred: 153
# at parameter set: (0.97, -0.51)
# cost calculatred: 149
# at parameter set: (0.97, -0.5)
# cost calculatred: 149
# at parameter set: (0.97, -0.49)
# cost calculatred: 150
# at parameter set: (0.97, -0.48)
# cost calculatred: 148
# at parameter set: (0.97, -0.47)
# cost calculatred: 146
# at parameter set: (0.97, -0.46)
# cost calculatred: 145
# at parameter set: (0.97, -0.45)
# cost calculatred: 144
# at parameter set: (0.97, -0.44)
# cost calculatred: 142
# at parameter set: (0.97, -0.43)
# cost calculatred: 143
# at parameter set: (0.97, -0.42)
# cost calculatred: 143
# at parameter set: (0.97, -0.41)
# cost calculatred: 142
# at parameter set: (0.97, -0.4)
# cost calculatred: 141
# at parameter set: (0.97, -0.39)
# cost calculatred: 141
# at parameter set: (0.97, -0.38)
# cost calculatred: 140
# at parameter set: (0.97, -0.37)
# cost calculatred: 139
# at parameter set: (0.97, -0.36)
# cost calculatred: 138
# at parameter set: (0.97, -0.35)
# cost calculatred: 138
# at parameter set: (0.97, -0.34)
# cost calculatred: 137
# at parameter set: (0.97, -0.33)
# cost calculatred: 138
# at parameter set: (0.97, -0.32)
# cost calculatred: 135
# at parameter set: (0.97, -0.31)
# cost calculatred: 133
# at parameter set: (0.97, -0.3)
# cost calculatred: 131
# at parameter set: (0.97, -0.29)
# cost calculatred: 131
# at parameter set: (0.97, -0.28)
# cost calculatred: 133
# at parameter set: (0.97, -0.27)
# cost calculatred: 134
# at parameter set: (0.97, -0.26)
# cost calculatred: 135
# at parameter set: (0.97, -0.25)
# cost calculatred: 135
# at parameter set: (0.97, -0.24)
# cost calculatred: 134
# at parameter set: (0.97, -0.23)
# cost calculatred: 135
# at parameter set: (0.97, -0.22)
# cost calculatred: 134
# at parameter set: (0.97, -0.21)
# cost calculatred: 135
# at parameter set: (0.97, -0.2)
# cost calculatred: 136
# at parameter set: (0.97, -0.19)
# cost calculatred: 136
# at parameter set: (0.97, -0.18)
# cost calculatred: 135
# at parameter set: (0.97, -0.17)
# cost calculatred: 135
# at parameter set: (0.97, -0.16)
# cost calculatred: 132
# at parameter set: (0.97, -0.15)
# cost calculatred: 131
# at parameter set: (0.97, -0.14)
# cost calculatred: 130
# at parameter set: (0.97, -0.13)
# cost calculatred: 130
# at parameter set: (0.97, -0.12)
# cost calculatred: 130
# at parameter set: (0.97, -0.11)
# cost calculatred: 130
# at parameter set: (0.97, -0.1)
# cost calculatred: 130
# at parameter set: (0.97, -0.09)
# cost calculatred: 130
# at parameter set: (0.97, -0.08)
# cost calculatred: 128
# at parameter set: (0.97, -0.07)
# cost calculatred: 127
# at parameter set: (0.97, -0.06)
# cost calculatred: 127
# at parameter set: (0.97, -0.05)
# cost calculatred: 127
# at parameter set: (0.97, -0.04)
# cost calculatred: 126
# at parameter set: (0.97, -0.03)
# cost calculatred: 126
# at parameter set: (0.97, -0.02)
# cost calculatred: 127
# at parameter set: (0.97, -0.01)
# cost calculatred: 14712
# at parameter set: (0.98, -1.0)
# cost calculatred: 5485
# at parameter set: (0.98, -0.99)
# cost calculatred: 3219
# at parameter set: (0.98, -0.98)
# cost calculatred: 2226
# at parameter set: (0.98, -0.97)
# cost calculatred: 1684
# at parameter set: (0.98, -0.96)
# cost calculatred: 1342
# at parameter set: (0.98, -0.95)
# cost calculatred: 1113
# at parameter set: (0.98, -0.94)
# cost calculatred: 941
# at parameter set: (0.98, -0.93)
# cost calculatred: 818
# at parameter set: (0.98, -0.92)
# cost calculatred: 717
# at parameter set: (0.98, -0.91)
# cost calculatred: 645
# at parameter set: (0.98, -0.9)
# cost calculatred: 579
# at parameter set: (0.98, -0.89)
# cost calculatred: 524
# at parameter set: (0.98, -0.88)
# cost calculatred: 481
# at parameter set: (0.98, -0.87)
# cost calculatred: 444
# at parameter set: (0.98, -0.86)
# cost calculatred: 413
# at parameter set: (0.98, -0.85)
# cost calculatred: 389
# at parameter set: (0.98, -0.84)
# cost calculatred: 365
# at parameter set: (0.98, -0.83)
# cost calculatred: 342
# at parameter set: (0.98, -0.82)
# cost calculatred: 322
# at parameter set: (0.98, -0.81)
# cost calculatred: 308
# at parameter set: (0.98, -0.8)
# cost calculatred: 291
# at parameter set: (0.98, -0.79)
# cost calculatred: 279
# at parameter set: (0.98, -0.78)
# cost calculatred: 268
# at parameter set: (0.98, -0.77)
# cost calculatred: 259
# at parameter set: (0.98, -0.76)
# cost calculatred: 247
# at parameter set: (0.98, -0.75)
# cost calculatred: 238
# at parameter set: (0.98, -0.74)
# cost calculatred: 232
# at parameter set: (0.98, -0.73)
# cost calculatred: 218
# at parameter set: (0.98, -0.72)
# cost calculatred: 214
# at parameter set: (0.98, -0.71)
# cost calculatred: 212
# at parameter set: (0.98, -0.7)
# cost calculatred: 207
# at parameter set: (0.98, -0.69)
# cost calculatred: 203
# at parameter set: (0.98, -0.68)
# cost calculatred: 198
# at parameter set: (0.98, -0.67)
# cost calculatred: 192
# at parameter set: (0.98, -0.66)
# cost calculatred: 190
# at parameter set: (0.98, -0.65)
# cost calculatred: 187
# at parameter set: (0.98, -0.64)
# cost calculatred: 185
# at parameter set: (0.98, -0.63)
# cost calculatred: 181
# at parameter set: (0.98, -0.62)
# cost calculatred: 177
# at parameter set: (0.98, -0.61)
# cost calculatred: 173
# at parameter set: (0.98, -0.6)
# cost calculatred: 172
# at parameter set: (0.98, -0.59)
# cost calculatred: 169
# at parameter set: (0.98, -0.58)
# cost calculatred: 168
# at parameter set: (0.98, -0.57)
# cost calculatred: 162
# at parameter set: (0.98, -0.56)
# cost calculatred: 161
# at parameter set: (0.98, -0.55)
# cost calculatred: 157
# at parameter set: (0.98, -0.54)
# cost calculatred: 158
# at parameter set: (0.98, -0.53)
# cost calculatred: 158
# at parameter set: (0.98, -0.52)
# cost calculatred: 154
# at parameter set: (0.98, -0.51)
# cost calculatred: 152
# at parameter set: (0.98, -0.5)
# cost calculatred: 151
# at parameter set: (0.98, -0.49)
# cost calculatred: 151
# at parameter set: (0.98, -0.48)
# cost calculatred: 150
# at parameter set: (0.98, -0.47)
# cost calculatred: 149
# at parameter set: (0.98, -0.46)
# cost calculatred: 146
# at parameter set: (0.98, -0.45)
# cost calculatred: 145
# at parameter set: (0.98, -0.44)
# cost calculatred: 144
# at parameter set: (0.98, -0.43)
# cost calculatred: 142
# at parameter set: (0.98, -0.42)
# cost calculatred: 143
# at parameter set: (0.98, -0.41)
# cost calculatred: 143
# at parameter set: (0.98, -0.4)
# cost calculatred: 142
# at parameter set: (0.98, -0.39)
# cost calculatred: 142
# at parameter set: (0.98, -0.38)
# cost calculatred: 141
# at parameter set: (0.98, -0.37)
# cost calculatred: 140
# at parameter set: (0.98, -0.36)
# cost calculatred: 139
# at parameter set: (0.98, -0.35)
# cost calculatred: 139
# at parameter set: (0.98, -0.34)
# cost calculatred: 138
# at parameter set: (0.98, -0.33)
# cost calculatred: 138
# at parameter set: (0.98, -0.32)
# cost calculatred: 137
# at parameter set: (0.98, -0.31)
# cost calculatred: 136
# at parameter set: (0.98, -0.3)
# cost calculatred: 134
# at parameter set: (0.98, -0.29)
# cost calculatred: 132
# at parameter set: (0.98, -0.28)
# cost calculatred: 131
# at parameter set: (0.98, -0.27)
# cost calculatred: 133
# at parameter set: (0.98, -0.26)
# cost calculatred: 134
# at parameter set: (0.98, -0.25)
# cost calculatred: 135
# at parameter set: (0.98, -0.24)
# cost calculatred: 135
# at parameter set: (0.98, -0.23)
# cost calculatred: 135
# at parameter set: (0.98, -0.22)
# cost calculatred: 136
# at parameter set: (0.98, -0.21)
# cost calculatred: 135
# at parameter set: (0.98, -0.2)
# cost calculatred: 136
# at parameter set: (0.98, -0.19)
# cost calculatred: 136
# at parameter set: (0.98, -0.18)
# cost calculatred: 136
# at parameter set: (0.98, -0.17)
# cost calculatred: 135
# at parameter set: (0.98, -0.16)
# cost calculatred: 135
# at parameter set: (0.98, -0.15)
# cost calculatred: 134
# at parameter set: (0.98, -0.14)
# cost calculatred: 131
# at parameter set: (0.98, -0.13)
# cost calculatred: 131
# at parameter set: (0.98, -0.12)
# cost calculatred: 131
# at parameter set: (0.98, -0.11)
# cost calculatred: 131
# at parameter set: (0.98, -0.1)
# cost calculatred: 130
# at parameter set: (0.98, -0.09)
# cost calculatred: 131
# at parameter set: (0.98, -0.08)
# cost calculatred: 130
# at parameter set: (0.98, -0.07)
# cost calculatred: 131
# at parameter set: (0.98, -0.06)
# cost calculatred: 128
# at parameter set: (0.98, -0.05)
# cost calculatred: 128
# at parameter set: (0.98, -0.04)
# cost calculatred: 128
# at parameter set: (0.98, -0.03)
# cost calculatred: 127
# at parameter set: (0.98, -0.02)
# cost calculatred: 127
# at parameter set: (0.98, -0.01)
# cost calculatred: 15023
# at parameter set: (0.99, -1.0)
# cost calculatred: 5602
# at parameter set: (0.99, -0.99)
# cost calculatred: 3288
# at parameter set: (0.99, -0.98)
# cost calculatred: 2279
# at parameter set: (0.99, -0.97)
# cost calculatred: 1718
# at parameter set: (0.99, -0.96)
# cost calculatred: 1372
# at parameter set: (0.99, -0.95)
# cost calculatred: 1136
# at parameter set: (0.99, -0.94)
# cost calculatred: 964
# at parameter set: (0.99, -0.93)
# cost calculatred: 833
# at parameter set: (0.99, -0.92)
# cost calculatred: 735
# at parameter set: (0.99, -0.91)
# cost calculatred: 657
# at parameter set: (0.99, -0.9)
# cost calculatred: 592
# at parameter set: (0.99, -0.89)
# cost calculatred: 537
# at parameter set: (0.99, -0.88)
# cost calculatred: 490
# at parameter set: (0.99, -0.87)
# cost calculatred: 453
# at parameter set: (0.99, -0.86)
# cost calculatred: 419
# at parameter set: (0.99, -0.85)
# cost calculatred: 394
# at parameter set: (0.99, -0.84)
# cost calculatred: 371
# at parameter set: (0.99, -0.83)
# cost calculatred: 349
# at parameter set: (0.99, -0.82)
# cost calculatred: 331
# at parameter set: (0.99, -0.81)
# cost calculatred: 316
# at parameter set: (0.99, -0.8)
# cost calculatred: 296
# at parameter set: (0.99, -0.79)
# cost calculatred: 282
# at parameter set: (0.99, -0.78)
# cost calculatred: 275
# at parameter set: (0.99, -0.77)
# cost calculatred: 263
# at parameter set: (0.99, -0.76)
# cost calculatred: 253
# at parameter set: (0.99, -0.75)
# cost calculatred: 244
# at parameter set: (0.99, -0.74)
# cost calculatred: 238
# at parameter set: (0.99, -0.73)
# cost calculatred: 227
# at parameter set: (0.99, -0.72)
# cost calculatred: 216
# at parameter set: (0.99, -0.71)
# cost calculatred: 213
# at parameter set: (0.99, -0.7)
# cost calculatred: 210
# at parameter set: (0.99, -0.69)
# cost calculatred: 205
# at parameter set: (0.99, -0.68)
# cost calculatred: 200
# at parameter set: (0.99, -0.67)
# cost calculatred: 195
# at parameter set: (0.99, -0.66)
# cost calculatred: 191
# at parameter set: (0.99, -0.65)
# cost calculatred: 191
# at parameter set: (0.99, -0.64)
# cost calculatred: 187
# at parameter set: (0.99, -0.63)
# cost calculatred: 183
# at parameter set: (0.99, -0.62)
# cost calculatred: 180
# at parameter set: (0.99, -0.61)
# cost calculatred: 176
# at parameter set: (0.99, -0.6)
# cost calculatred: 174
# at parameter set: (0.99, -0.59)
# cost calculatred: 172
# at parameter set: (0.99, -0.58)
# cost calculatred: 168
# at parameter set: (0.99, -0.57)
# cost calculatred: 166
# at parameter set: (0.99, -0.56)
# cost calculatred: 163
# at parameter set: (0.99, -0.55)
# cost calculatred: 158
# at parameter set: (0.99, -0.54)
# cost calculatred: 157
# at parameter set: (0.99, -0.53)
# cost calculatred: 157
# at parameter set: (0.99, -0.52)
# cost calculatred: 158
# at parameter set: (0.99, -0.51)
# cost calculatred: 153
# at parameter set: (0.99, -0.5)
# cost calculatred: 152
# at parameter set: (0.99, -0.49)
# cost calculatred: 151
# at parameter set: (0.99, -0.48)
# cost calculatred: 152
# at parameter set: (0.99, -0.47)
# cost calculatred: 151
# at parameter set: (0.99, -0.46)
# cost calculatred: 150
# at parameter set: (0.99, -0.45)
# cost calculatred: 147
# at parameter set: (0.99, -0.44)
# cost calculatred: 144
# at parameter set: (0.99, -0.43)
# cost calculatred: 142
# at parameter set: (0.99, -0.42)
# cost calculatred: 141
# at parameter set: (0.99, -0.41)
# cost calculatred: 143
# at parameter set: (0.99, -0.4)
# cost calculatred: 143
# at parameter set: (0.99, -0.39)
# cost calculatred: 142
# at parameter set: (0.99, -0.38)
# cost calculatred: 142
# at parameter set: (0.99, -0.37)
# cost calculatred: 141
# at parameter set: (0.99, -0.36)
# cost calculatred: 140
# at parameter set: (0.99, -0.35)
# cost calculatred: 139
# at parameter set: (0.99, -0.34)
# cost calculatred: 139
# at parameter set: (0.99, -0.33)
# cost calculatred: 139
# at parameter set: (0.99, -0.32)
# cost calculatred: 138
# at parameter set: (0.99, -0.31)
# cost calculatred: 136
# at parameter set: (0.99, -0.3)
# cost calculatred: 136
# at parameter set: (0.99, -0.29)
# cost calculatred: 134
# at parameter set: (0.99, -0.28)
# cost calculatred: 133
# at parameter set: (0.99, -0.27)
# cost calculatred: 131
# at parameter set: (0.99, -0.26)
# cost calculatred: 133
# at parameter set: (0.99, -0.25)
# cost calculatred: 134
# at parameter set: (0.99, -0.24)
# cost calculatred: 134
# at parameter set: (0.99, -0.23)
# cost calculatred: 135
# at parameter set: (0.99, -0.22)
# cost calculatred: 135
# at parameter set: (0.99, -0.21)
# cost calculatred: 136
# at parameter set: (0.99, -0.2)
# cost calculatred: 135
# at parameter set: (0.99, -0.19)
# cost calculatred: 136
# at parameter set: (0.99, -0.18)
# cost calculatred: 136
# at parameter set: (0.99, -0.17)
# cost calculatred: 137
# at parameter set: (0.99, -0.16)
# cost calculatred: 136
# at parameter set: (0.99, -0.15)
# cost calculatred: 136
# at parameter set: (0.99, -0.14)
# cost calculatred: 135
# at parameter set: (0.99, -0.13)
# cost calculatred: 133
# at parameter set: (0.99, -0.12)
# cost calculatred: 131
# at parameter set: (0.99, -0.11)
# cost calculatred: 132
# at parameter set: (0.99, -0.1)
# cost calculatred: 131
# at parameter set: (0.99, -0.09)
# cost calculatred: 131
# at parameter set: (0.99, -0.08)
# cost calculatred: 132
# at parameter set: (0.99, -0.07)
# cost calculatred: 132
# at parameter set: (0.99, -0.06)
# cost calculatred: 133
# at parameter set: (0.99, -0.05)
# cost calculatred: 129
# at parameter set: (0.99, -0.04)
# cost calculatred: 128
# at parameter set: (0.99, -0.03)
# cost calculatred: 128
# at parameter set: (0.99, -0.02)
# cost calculatred: 127
# at parameter set: (0.99, -0.01)
# [ 0.43576789 -0.69876311]
# [ 0.43581173 -0.69874022]
# 0.436 -0.699
